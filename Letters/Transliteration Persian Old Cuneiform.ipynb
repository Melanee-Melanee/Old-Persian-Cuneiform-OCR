# %% [markdown]
# # Transliteration-Persian-Old-Cuneiform

# %%
char_map = {
"𐎠":"a",
"𐎡":"ii", 
"𐎢":"ū", 
"𐎣":"ka",  
"𐎤":"ku",  
"𐎥":"ga",  
"𐎦":"gu",  
"𐎧":"x", 
"𐎨":"c",  
"𐎩":"ja",  
"𐎪":"ji",  
"𐎫":"ta",  
"𐎬":"tu",  
"𐎭":"da",  
"𐎮":"di",  
"𐎯":"du",
"𐎰":"th",  
"𐎱":"p", 
"𐎲":"b", 
"𐎳":"f", 
"𐎴":"na",
"𐎵":"nu", 
"𐎶":"ma",
"𐎷":"mi", 
"𐎸":"mu",
"𐎹":"y", 
"𐎺":"va",  
"𐎻":"vi",  
"𐎼":"ra", 
"𐎽":"ru", 
"𐎾":"r",
"𐎿":"s",  
"𐏀":"z",  
"𐏁":"sh", 
"𐏂":"ss",
"𐏃":"h",  
"𐏐": " ",
"𐏑":"1",
"𐏒":"2",
"𐏓":"10", 
"𐏔":"20",
"𐏕":"100",
"𐏋":"king",
"𐏏":"earth",
"𐏌𐏍":"country",
"𐏎":"God",
"𐏈𐏉":"Auramazda",
"𐏊":"Auramazdaha",

}

# %%
def replace_characters_with_custom(original_string, char_map):
    # Create a new string by replacing each character according to the dictionary
    new_string = ''.join(char_map.get(char, char)
    for char in original_string)
    return new_string

# %%
original_string = input('Enter your Cuneiform: ')   #example:𐎭𐎠𐎾𐎹𐎺𐎢𐏁𐏐𐏋
new_string = replace_characters_with_custom(original_string, char_map)
print('Transliteration:',new_string)
# Out:
# Enter your Cuneiform: 𐎭𐎠𐎾𐎹𐎺𐎢𐏁𐏐𐏋
# Transliteration: daaryvaūsh king

# %% [markdown]
# # All Persian Old cuneiform letters:

# %% [markdown]
# Persian old language has 36 main letters which are illustrated below:

# %% [markdown]
# ![n1.JPG](attachment:n1.JPG)

# %% [markdown]
# ![n2.JPG](attachment:n2.JPG)

# %% [markdown]
# This notebook is developed by Melanee: https://github.com/Melanee-Melanee/Persian-Old-Cuneiform/tree/main
