# %% [markdown]
# # OCR on Old Persian cuneiform
#
# This pre-trained OCR model deciphers Old Persian cuneiform to English transcription and is developed by S. Muhammad Hossein Mousavi.:
#
# https://github.com/SeyedMuhammadHosseinMousavi/Extracting-Old-Persian-Cuneiform/tree/main
#
#
# The code of this notebook is developed by Melanee:
#
# https://github.com/Melanee-Melanee/Old-Persian-Cuneiform-OCR

# %%
# !pip install pytesseract

#pytesseravt version = 0.3.10

# %%
# !apt-get install tesseract-ocr

#tesseract-ocr version = 4.1.1-2.1build1
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 2s (2,639 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 121926 files and directories currently installed.)
# ...

# %%
# !pip install pillow

#Pillow version = 9.4.0

# %%
from PIL import Image
import pytesseract

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.15.0
# backcall                         0.2.0
# ...

# %% [markdown]
# ## Find tesseracr executable path

# %%
#to check where is tesseract
# !which tesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %% [markdown]
# # Old Persian OCR

# %%
# mount this notebook to Goole Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd /usr/share/tesseract-ocr/4.00/tessdata/
# Out:
# /usr/share/tesseract-ocr/4.00/tessdata

# %% [markdown]
# ##Please replace "op.traineddata" file in this directory: /usr/share/tesseract-ocr/4.00/tessdata

# %%
# !mv /content/drive/MyDrive/Persiancuneiform1/tesseract/op.traineddata /usr/share/tesseract-ocr/4.00/tessdata

# %%
# !ls /usr/share/tesseract-ocr/4.00/tessdata

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/Persiancuneiform1/d1.JPG')
imgplot = plt.imshow(img)
plt.show()

# %%
img_path ='/content/drive/MyDrive/Persiancuneiform1/d1.JPG'
img = Image.open(img_path)

# %%
text = pytesseract.image_to_string(img, lang='op')

# %%
print(text)
# Out:
# Zatiy ; dalyvu S ; xSay
# Zdy mna;aul bpmma;u stam;
# blT uv; Nnda ; VdZdbiS ; bgd
# bdS;uta;dmam;dhyaum;aul
# mzda ; paTuv ; Qca;hd bay
# a;Qca ; QuSdyala ; Nnca; dl
# uga ;abdy ;dmam ;dhyaum ;ma
#
# ;ajM iya

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/Persiancuneiform1/darius.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img_path ='/content/drive/MyDrive/Persiancuneiform1/darius.png'
img = Image.open(img_path)

# %%
text = pytesseract.image_to_string(img, lang='op')

# %%
print(text)
# Out:
# b T ; v z r k ; a u rt z i a ; Q y ; i tma t
#
# ; b u M i t ; a i a ; Q y ; a v t ; a s tma n t
#
# ; aia ; Qy ;trtiyt ; aia ; ny
#
# ; S i y a t i t ; a i a ; trt i y Q y a
#
# ; Q y ; i a r f s u t ; xS a y Z i y t ; a Kx n u S

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/Persiancuneiform1/d2.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img_path ='/content/drive/MyDrive/Persiancuneiform1/d2.png'
img = Image.open(img_path)

# %%
text = pytesseract.image_to_string(img, lang='op')

# %%
print(text)
# Out:
# bur;rszrk;aurbazda ;Sny ;dlaardr;buMca;a
# da;hy;arkm;asmafm;ada;hy;mrtdym;ada
# ;Qy ;Sdyabbdba ; ada ;larbbdyNbya ;Rby ;dar
# ycsura ; Eyra ; aKunuS ; adbsba ; dRubarZ ; rKK

# %% [markdown]
# ## This photo is The last 12 lines of the great Darius's inscription in Persepolis, DPd inscription:
# https://www.livius.org/sources/content/achaemenid-royal-inscriptions/dpd/

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/Persiancuneiform1/darius2.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img_path ='/content/drive/MyDrive/Persiancuneiform1/darius2.png'
img = Image.open(img_path)

# %%
text = pytesseract.image_to_string(img, lang='op')

# %%
print(text)
# Out:
# Zittiy ; iaryvuS ; xrSayZiy;
# mnc;aurmzia;upstam; rlauv;
# hia ; ViZiriS ; rgiriS ; uta;
# im am ; i h yaum ; au lm z i a ;
# pitTucs;hca;hinaya; hca;
# QuSiyala ; hca;iruga;ariy;
# imam ;ihyaum;ma; ajMiya; ait;
# aim ;yanm;jDiyaMiy;
#
# aitmiy ; iiaTuv

# %% [markdown]
# ##To translate those output (english transcriptions) please use [ChatGPT](https://chatgpt.com/)
#
# Type this command on ChatGPT: please translate this Old Persian transcription to modern Persian language: "type transcription here"
